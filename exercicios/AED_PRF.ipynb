# %% [markdown]
# **Tarefa 1: Obtenção dos conjunto de dados e suas informações**

# %% [markdown]
# 1 - Fazer download nesse [link](https://www.gov.br/prf/pt-br/acesso-a-informacao/dados-abertos/dados-abertos-da-prf) de todos os conjuntos de dados de acidentes e de multas, entre os anos
# de 2018 e 2025, além dos dicionários de dados relacionados;
#
# ---
#
# Download dos arquivos hospedados no Mega (via link de download direto) utilizando megadl.
#
# Dessa forma é possível economizar armazenamento local e fazer upload do notebook para o GitHub sem erros de limite de armazenamento. O processo pode demorar um pouco, mas a execução dos blocos de código só é feita uma única vez.
#
# Os arquivos estão armazenados em:
# - INFRAÇÕES (MULTAS): https://mega.nz/folder/NnpHxSaD#zVB4QFDj03QeT_F0BR6tUQ
#
# - ACIDENTES - AGRUPADOS POR OCORRÊNCIA: https://mega.nz/folder/RqZHyLgS#7sA4uIbpQP_-cif43HpUEQ

# %%
# Este bloco de código é dedicado ao download dos datasets de INFRAÇÕES 2018-2025
# Cada arquivo de saída foi nomeado conforme o ano da extração dos dados
# Os arquivos após o download estarão na pasta /content/infracoes

# !apt-get install -y megatools # Instala o pacote necessário para fazer a requisição de download
# !mkdir infracoes # Cria dinamicamente a pasta para armazenar os arquivos

# !megadl "https://mega.nz/file/96wmRJRD#WPmLGUJYa84aYR3Qrnrko7zthxGuRL5VuuwK1g62jwI" \
  --path /content/infracoes/infracoes_2018.zip

# !megadl "https://mega.nz/file/U2RnnCob#KaxB6Upbmu0DLCyzY0kPJ4ZjDgql0Rt-mSEWRacJPCQ" \
  --path /content/infracoes/infracoes_2019.zip

# !megadl "https://mega.nz/file/o2BViKgZ#tvSw623e_nTlNX-sZb69-Lq1Km7RhipRgTd6LFdhRbU" \
  --path /content/infracoes/infracoes_2020.zip

# !megadl "https://mega.nz/file/k3RS1JwZ#jf0hnP6Jy9K9SzH1_vyS-BaQlMF4vO5n2G-a6Ge0vvI" \
  --path /content/infracoes/infracoes_2021.zip

# !megadl "https://mega.nz/file/Iyhn0RiJ#9g6H2wWDEgFyzw5tuLAqFTfScwcPc1tDYyqRZdrbZHg" \
  --path /content/infracoes/infracoes_2022.zip

# !megadl "https://mega.nz/file/82YiSZKS#yK7cRc20ZqcV6AlZfavFYF2-tM4B1alTf6GK-ifR-qY" \
  --path /content/infracoes/infracoes_2023.zip

# !megadl "https://mega.nz/file/4uZlCS4I#gHksZlOPTu9arNj-7e2tMl5lRNpwp1NFASOz9Oa0e_Y" \
  --path /content/infracoes/infracoes_2024.zip

# !megadl "https://mega.nz/file/1nwTSTBC#OHmSACYGagRV2ZMAl7F9ktTu5PX3uUbpC_-47VgRcSo" \
  --path /content/infracoes/infracoes_2025.zip

print("\033[32mDownload finalizado!\033[m")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   megatools
# 0 upgraded, 1 newly installed, 0 to remove and 2 not upgraded.
# Need to get 207 kB of archives.
# After this operation, 898 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 megatools amd64 1.10.3-1build1 [207 kB]
# Fetched 207 kB in 1s (336 kB/s)
# Selecting previously unselected package megatools.
# (Reading database ... 118194 files and directories currently installed.)
# Preparing to unpack .../megatools_1.10.3-1build1_amd64.deb ...
# Unpacking megatools (1.10.3-1build1) ...
# Setting up megatools (1.10.3-1build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Downloaded infracoes_2018.zip
# Downloaded infracoes_2019.zip
# Downloaded infracoes_2020.zip
# Downloaded infrações_2021.zip
# Downloaded infrações_2022.zip
# Downloaded infrações_2023.zip
# Downloaded infrações_2024.zip
# Downloaded infrações_2025.zip
# Download finalizado!

# %%
# Este bloco de código é dedicado ao download dos datasets de ACIDENTES AGRUPADOS POR OCORRÊNCIA 2018-2025
# Cada arquivo de saída foi nomeado conforme o ano da extração dos dados
# Os arquivos após o download estarão na pasta /content/acidentes

# !mkdir acidentes # Cria dinamicamente a pasta para armazenar os arquivos

# !megadl "https://mega.nz/file/VnIG0SgI#7RX1owbScp7IgRU06UwvsKZUpkZyDstV73G7jKYf6nY" \
  --path /content/acidentes/acidentes_2018.zip

# !megadl "https://mega.nz/file/c2BlUCoJ#dDU3MTBHBBzKXd-_SpT_Lj2wLzhUSAn7fQIoOU7oRpM" \
  --path /content/acidentes/acidentes_2019.zip

# !megadl "https://mega.nz/file/trIyCApL#6XQALuWfLYNG3liRGv37Q737aOFWfIaaw8nabkjFt4U" \
  --path /content/acidentes/acidentes_2020.zip

# !megadl "https://mega.nz/file/1mgwwAKL#0ff5c_m-SUtZJhRGSn_PTSW23HyJ3hhGtXq3s9Hat6w" \
  --path /content/acidentes/acidentes_2021.zip

# !megadl "https://mega.nz/file/Z3glnB7J#kY_rOQ_I71T42nrUfp5rMsLBAlk0Ft2ecFRUIpFMcDo" \
  --path /content/acidentes/acidentes_2022.zip

# !megadl "https://mega.nz/file/JyIkXSjJ#P8C3OmJDQaPun8REyth_0xvw-ekHLXG93fgITTVc9qE" \
  --path /content/acidentes/acidentes_2023.zip

# !megadl "https://mega.nz/file/Y3ZQxZxY#Bd--J642FeG6Ugu-PLKc4CXoHqev4ILC_aZ5IzubKUI" \
  --path /content/acidentes/acidentes_2024.zip

# !megadl "https://mega.nz/file/AioT2QwY#UDcswOFWQPvxAL5eiOy8xusiHD9fZmAwlfIuip2eP7M" \
  --path /content/acidentes/acidentes_2025.zip

print("\033[32mDownload finalizado!\033[m")
# Out:
# Downloaded datatran2018.zip
# Downloaded datatran2019.zip
# Downloaded datatran2020.zip
# Downloaded datatran2021.zip
# Downloaded datatran2022.zip
# Downloaded datatran2023.zip
# Downloaded datatran2024.zip
# Downloaded datatran2025.zip
# Download finalizado!

# %%
# Padronização de todos os datasets antes de prosseguir com as demais questões
import zipfile
import shutil
import os

# Funções úteis

def new_dir(caminho, pastas):
  """
    Cria novos diretórios a partir de um array
    e extrai os arquivos zipados dinamicamente
  """
  try:
    for pasta in pastas:
      # Cria uma nova pasta caso ainda não exista
      if not os.path.isdir(f"{caminho}/{pasta}"):
        os.mkdir(f"{caminho}/{pasta}")

      # Extrai os arquivos dinamicamente
      arquivo = f"{caminho}/{pasta}.zip"
      with zipfile.ZipFile(f"{arquivo}") as dataset:
        dataset.extractall(path=f"{caminho}/{pasta}")
    print("\033[32mArquivos extraídos com sucesso!\033[m")

  except Exception as e:
    print(f"\033[31mErro ao extrair os arquivos: {e}\033[m")

def move_file(caminho, pastas):
  """
    Percorre os diretórios raiz e, se houver
    subpastas, move os arquivos para a pasta
    raiz e remove a subpasta
  """
  try:
    for pasta in pastas:
      pasta_raiz = f"{caminho}/{pasta}"
      # Verifica se há uma subpasta na pasta atual
      subdir = [name for name in os.listdir(pasta_raiz) if os.path.isdir(os.path.join(pasta_raiz, name))]
      if subdir:
        subpasta = f"{pasta_raiz}/{subdir[0]}"
        for arquivo in os.listdir(subpasta):
          if arquivo.endswith(".csv"):
            origem = os.path.join(subpasta, arquivo)
            destino = os.path.join(pasta_raiz, arquivo)
            shutil.move(origem, destino)
        # Remove a subpasta
        shutil.rmtree(subpasta)
    print("\033[32mArquivos movidos com sucesso!\033[m")

  except Exception as e:
    print(f"\033[31mErro ao mover arquivos de subpastas: {e}\033[m")

# %%
# Datasets de INFRAÇÕES (MULTAS) 2018-2025
# Criando as pastas e extraindo os arquivos .zip de infrações 2018-2025
pastas = [
    "infracoes_2018", "infracoes_2019", "infracoes_2020", "infracoes_2021",
    "infracoes_2022", "infracoes_2023", "infracoes_2024", "infracoes_2025"
]

infra_path = "/content/infracoes"

# Cria pastas individuais para cada infração por ano chamando a função new_dir
new_dir(infra_path, pastas)

# Algumas pastas não seguem o padrão de infracoes_20XX_XX.csv
# É necessário realizar o tratamento individual dessas pastas
# para que todos os datasets sigam o mesmo modelo

# Checa se dentro do diretório raiz há uma subpasta
move_file(infra_path, pastas)

# %%
# Alguns arquivos não seguem o padrão de infracoes_ANO_MES.csv
# esses arquivos precisam ser renomeados para se adequar ao padrão

anos = [
    "2018", "2019", "2020", "2021",
    "2022", "2023", "2024", "2025"
]

meses = ["jan", "fev", "mar", "abr", "mai", "jun",
         "jul", "ago", "set", "out", "nov", "dez"]

# Laço para renomear arquivos
for i, pasta in enumerate(pastas):
    caminho_pasta = f"{infra_path}/{pasta}"

    for arquivo in os.listdir(caminho_pasta):
        nome, ext = os.path.splitext(arquivo)

        # Arquivo no padrão correto —> ignora
        if nome.startswith("infracoes_"):
            continue

        # Arquivo no formato infraçoes_ANO_MES.csv
        elif nome.startswith("infraçoes_"):
            novo_nome = nome.replace("infraçoes_", "infracoes_") + ".csv"

        # Arquivo no formato infraçoesANO_MES.csv
        elif nome.startswith("infraçoes"):
            novo_nome = nome.replace("infraçoes", "infracoes_") + ".csv"

        # Arquivo no formato MES.csv
        elif nome in meses:
            mes_num = meses.index(nome) + 1
            novo_nome = f"infracoes_{anos[i]}_{mes_num:02d}.csv"

        os.rename(
            os.path.join(caminho_pasta, arquivo),
            os.path.join(caminho_pasta, novo_nome)
        )

# %%
# Datasets de ACIDENTES 2018-2025
pastas_acidentes = [
    "acidentes_2018", "acidentes_2019", "acidentes_2020", "acidentes_2021",
    "acidentes_2022","acidentes_2023", "acidentes_2024", "acidentes_2025"
]

aci_path = "/content/acidentes"

# Cria pastas individuais para cada acidente por ano chamando a função new_dir
new_dir(aci_path, pastas_acidentes)
# Out:
# Arquivos extraídos com sucesso!

# %% [markdown]
# 2 - Conferir se as variáveis são as mesmas em todos os anos, para cada um dos cenários e levantar
# as diferenças entre a lista de variáveis do conjunto de dados de acidentes e de multas (nessa ação
# é necessário o auxílio do dicionário de dados, uma vez que variáveis podem ter nomenclaturas
# distintas, porém, mesmo significado).

# %%
import pandas as pd

# Unindo os datasets de infrações que são agrupados por meses em um único dataset por ano
ano = 2018
for pasta in pastas:
    frames = []

    if pasta == "infracoes_2018":
      encode = "ISO-8859-1"
      separador = ","
    elif pasta == "infracoes_2019":
      encode = "utf-8"
      separador = ";"
    elif pasta in ["infracoes_2020", "infracoes_2021", "infracoes_2022", "infracoes_2023", "infracoes_2024", "infracoes_2025"]:
      encode = "ISO-8859-1"
      separador = ";"

    for arquivo in os.listdir(f"{infra_path}/{pasta}"):
        if arquivo.endswith(".csv"):
            caminho_arquivo = os.path.join(f"{infra_path}/{pasta}", arquivo)
            df = pd.read_csv(caminho_arquivo, sep=separador, encoding=encode, low_memory=False)
            frames.append(df)

    # Exibe as infos dos dataframes provisórios para análise das colunas
    if frames:
        dataset = pd.concat(frames, ignore_index=True)
        print(f"====== {ano} ======")
        dataset.info()
        ano += 1
# Out:
# ====== 2018 ======
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7356159 entries, 0 to 7356158
# Data columns (total 22 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   dat_infracao             object
#  1   tip_abordagem            object
#  2   ind_assinou_auto         object
#  3   ind_veiculo_estrangeiro  object
#  4   ind_sentido_trafego      object
#  5   uf_placa                 object
#  6   uf_infracao              object
#  7   num_br_infracao          int64
#  8   num_km_infracao          int64
#  9   nom_municipio            object
#  10  cod_infracao             int64
#  11  descricao_abreviada      object
#  12  enquadramento            object
#  13  data_inicio_vigencia     object
#  14  data_fim_vigencia        object
#  15  med_realizada            float64
#  16  med_considerada          float64
#  17  exc_verificado           float64
#  18  especie                  object
#  19  nome_veiculo_marca       object
#  20  nom_modelo_veiculo       object
#  21  hora                     object
# dtypes: float64(3), int64(3), object(16)
# memory usage: 1.2+ GB
# ====== 2019 ======
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5742110 entries, 0 to 5742109
# Data columns (total 22 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   Número do Auto                 object
#  1   Data da Infração (DD/MM/AAAA)  object
#  2   Indicador de Abordagem         object
#  3   Assinatura do Auto             object
#  4   Indicador Veiculo Estrangeiro  object
#  5   Sentido Trafego                object
#  6   UF Placa                       object
#  7   UF Infração                    object
#  8   BR Infração                    int64
#  9   Km Infração                    int64
#  10  Município                      object
#  11  Código da Infração             int64
#  12  Descrição Abreviada Infração   object
#  13  Enquadramento da Infração      object
#  14  Início Vigência da Infração    object
#  15  Fim Vigência Infração          object
#  16  Medição Infração               object
#  17  Descrição Especie Veículo      object
#  18  Descrição Marca Veículo        object
#  19  Hora Infração                  int64
#  20  Medição Considerada            object
#  21  Excesso Verificado             object
# dtypes: int64(4), object(18)
# memory usage: 963.8+ MB
# ====== 2020 ======
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5182537 entries, 0 to 5182536
# Data columns (total 23 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   Número do Auto                 object
#  1   Data da Infração (DD/MM/AAAA)  object
#  2   Indicador de Abordagem         object
#  3   Assinatura do Auto             object
#  4   Indicador Veiculo Estrangeiro  object
#  5   Sentido Trafego                object
#  6   UF Infração                    object
#  7   BR Infração                    int64
#  8   Km Infração                    int64
#  9   Município                      object
#  10  Código da Infração             int64
#  11  Descrição Abreviada Infração   object
#  12  Enquadramento da Infração      object
#  13  Início Vigência da Infração    object
#  14  Fim Vigência Infração          object
#  15  Medição Infração               object
#  16  Descrição Especie Veículo      object
#  17  Descrição Marca Veículo        object
#  18  Hora Infração                  int64
#  19  Medição Considerada            object
#  20  Excesso Verificado             object
#  21  Qtd Infrações                  int64
#  22  UF Placa                       object
# dtypes: int64(5), object(18)
# memory usage: 909.4+ MB
# ====== 2021 ======
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5241299 entries, 0 to 5241298
# Data columns (total 22 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   Número do Auto                 object
#  1   Data da Infração (DD/MM/AAAA)  object
#  2   Indicador de Abordagem         object
#  3   Assinatura do Auto             object
#  4   Indicador Veiculo Estrangeiro  object
#  5   Sentido Trafego                object
#  6   UF Infração                    object
#  7   BR Infração                    int64
#  8   Km Infração                    int64
#  9   Município                      object
#  10  Código da Infração             int64
#  11  Descrição Abreviada Infração   object
#  12  Enquadramento da Infração      object
#  13  Início Vigência da Infração    object
#  14  Fim Vigência Infração          float64
#  15  Medição Infração               object
#  16  Descrição Especie Veículo      object
#  17  Descrição Marca Veículo        object
#  18  Hora Infração                  int64
#  19  Medição Considerada            object
#  20  Excesso Verificado             object
#  21  Qtd Infrações                  int64
# dtypes: float64(1), int64(5), object(16)
# memory usage: 879.7+ MB
# ====== 2022 ======
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4135523 entries, 0 to 4135522
# Data columns (total 25 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   Número do Auto                 object
#  1   Data da Infração (DD/MM/AAAA)  object
#  2   Indicador de Abordagem         object
#  3   Assinatura do Auto             object
#  4   Sentido Trafego                object
#  5   UF Infração                    object
#  6   BR Infração                    int64
#  7   Km Infração                    int64
#  8   Município                      object
#  9   Indicador Veiculo Estrangeiro  object
#  10  UF Placa                       object
#  11  Descrição Especie Veículo      object
#  12  Descrição Marca Veículo        object
#  13  Descrição Tipo Veículo         object
#  14  Descrição Modelo Veiculo       object
#  15  Código da Infração             int64
#  16  Descrição Abreviada Infração   object
#  17  Enquadramento da Infração      object
#  18  Início Vigência da Infração    object
#  19  Fim Vigência Infração          float64
#  20  Medição Infração               object
#  21  Hora Infração                  int64
#  22  Medição Considerada            object
#  23  Excesso Verificado             object
#  24  Qtd Infrações                  int64
# dtypes: float64(1), int64(5), object(19)
# memory usage: 788.8+ MB
# ====== 2023 ======
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5946483 entries, 0 to 5946482
# Data columns (total 25 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   Número do Auto                 object
#  1   Data da Infração (DD/MM/AAAA)  object
#  2   Indicador de Abordagem         object
#  3   Assinatura do Auto             object
#  4   Sentido Trafego                object
#  5   UF Infração                    object
#  6   BR Infração                    int64
#  7   Km Infração                    int64
#  8   Município                      object
#  9   Indicador Veiculo Estrangeiro  object
#  10  UF Placa                       object
#  11  Descrição Especie Veículo      object
#  12  Descrição Marca Veículo        object
#  13  Descrição Tipo Veículo         object
#  14  Descrição Modelo Veiculo       object
#  15  Código da Infração             int64
#  16  Descrição Abreviada Infração   object
#  17  Enquadramento da Infração      object
#  18  Início Vigência da Infração    object
#  19  Fim Vigência Infração          float64
#  20  Medição Infração               object
#  21  Hora Infração                  int64
#  22  Medição Considerada            object
#  23  Excesso Verificado             object
#  24  Qtd Infrações                  int64
# dtypes: float64(1), int64(5), object(19)
# memory usage: 1.1+ GB
# ====== 2024 ======
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8710022 entries, 0 to 8710021
# Data columns (total 25 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   Número do Auto                 object
#  1   Data da Infração (DD/MM/AAAA)  object
#  2   Indicador de Abordagem         object
#  3   Assinatura do Auto             object
#  4   Sentido Trafego                object
#  5   UF Infração                    object
#  6   BR Infração                    int64
#  7   Km Infração                    int64
#  8   Município                      object
#  9   Indicador Veiculo Estrangeiro  object
#  10  UF Placa                       object
#  11  Descrição Especie Veículo      object
#  12  Descrição Marca Veículo        object
#  13  Descrição Tipo Veículo         object
#  14  Descrição Modelo Veiculo       object
#  15  Código da Infração             object
#  16  Descrição Abreviada Infração   object
#  17  Enquadramento da Infração      object
#  18  Início Vigência da Infração    object
#  19  Fim Vigência Infração          float64
#  20  Medição Infração               object
#  21  Hora Infração                  int64
#  22  Medição Considerada            object
#  23  Excesso Verificado             object
#  24  Qtd Infrações                  float64
# dtypes: float64(2), int64(3), object(20)
# memory usage: 1.6+ GB
# ====== 2025 ======
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10204474 entries, 0 to 10204473
# Data columns (total 25 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   Número do Auto                 object
#  1   Data da Infração (DD/MM/AAAA)  object
#  2   Indicador de Abordagem         object
#  3   Assinatura do Auto             object
#  4   Sentido Trafego                object
#  5   UF Infração                    object
#  6   BR Infração                    int64
#  7   Km Infração                    int64
#  8   Município                      object
#  9   Indicador Veiculo Estrangeiro  object
#  10  UF Placa                       object
#  11  Descrição Especie Veículo      object
#  12  Descrição Marca Veículo        object
#  13  Descrição Tipo Veículo         object
#  14  Descrição Modelo Veiculo       object
#  15  Código da Infração             int64
#  16  Descrição Abreviada Infração   object
#  17  Enquadramento da Infração      object
#  18  Início Vigência da Infração    object
#  19  Fim Vigência Infração          float64
#  20  Medição Infração               object
#  21  Hora Infração                  int64
#  22  Medição Considerada            float64
#  23  Excesso Verificado             float64
#  24  Qtd Infrações                  int64
# dtypes: float64(3), int64(5), object(17)
# memory usage: 1.9+ GB

# %%
import pandas as pd
# Algumas colunas dos datasets de INFRAÇÕES possuem nomes distintos

# Mapeamento das colunas de 2018 para o padrão dos demais anos
colunas_2018 = {
    "dat_infracao":             "Data da Infração (DD/MM/AAAA)",
    "tip_abordagem":            "Indicador de Abordagem",
    "ind_assinou_auto":         "Assinatura do Auto",
    "ind_veiculo_estrangeiro":  "Indicador Veiculo Estrangeiro",
    "ind_sentido_trafego":      "Sentido Trafego",
    "uf_placa":                 "UF Placa",
    "uf_infracao":              "UF Infração",
    "num_br_infracao":          "BR Infração",
    "num_km_infracao":          "Km Infração",
    "nom_municipio":            "Município",
    "cod_infracao":             "Código da Infração",
    "descricao_abreviada":      "Descrição Abreviada Infração",
    "enquadramento":            "Enquadramento da Infração",
    "data_inicio_vigencia":     "Início Vigência da Infração",
    "data_fim_vigencia":        "Fim Vigência Infração",
    "med_realizada":            "Medição Infração",
    "med_considerada":          "Medição Considerada",
    "exc_verificado":           "Excesso Verificado",
    "especie":                  "Descrição Especie Veículo",
    "nome_veiculo_marca":       "Descrição Marca Veículo",
    "nom_modelo_veiculo":       "Descrição Modelo Veiculo",
    "hora":                     "Hora Infração",
}

# Renomeando as colunas do dataset de INFRAÇÕES de 2018
# INFRAÇÕES 2018
infra_2018_datasets = [
    f"{infra_path}/infracoes_2018/infracoes_2018_01.csv", f"{infra_path}/infracoes_2018/infracoes_2018_02.csv",
    f"{infra_path}/infracoes_2018/infracoes_2018_03.csv", f"{infra_path}/infracoes_2018/infracoes_2018_04.csv",
    f"{infra_path}/infracoes_2018/infracoes_2018_05.csv", f"{infra_path}/infracoes_2018/infracoes_2018_06.csv",
    f"{infra_path}/infracoes_2018/infracoes_2018_07.csv", f"{infra_path}/infracoes_2018/infracoes_2018_08.csv",
    f"{infra_path}/infracoes_2018/infracoes_2018_09.csv", f"{infra_path}/infracoes_2018/infracoes_2018_10.csv",
    f"{infra_path}/infracoes_2018/infracoes_2018_11.csv", f"{infra_path}/infracoes_2018/infracoes_2018_12.csv",
]

infra_2018 = [pd.read_csv(arquivo,sep=",",encoding="ISO-8859-1", low_memory=False) for arquivo in infra_2018_datasets]
df_infra_2018 = pd.concat(infra_2018, ignore_index=True)
df_infra_2018.rename(columns=colunas_2018, inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7356159 entries, 0 to 7356158
# Data columns (total 22 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   Data da Infração (DD/MM/AAAA)  object
#  1   Indicador de Abordagem         object
#  2   Assinatura do Auto             object
#  3   Indicador Veiculo Estrangeiro  object
#  4   Sentido Trafego                object
#  5   UF Placa                       object
#  6   UF Infração                    object
#  7   BR Infração                    int64
#  8   Km Infração                    int64
#  9   Município                      object
#  10  Código da Infração             int64
#  11  Descrição Abreviada Infração   object
#  12  Enquadramento da Infração      object
#  13  Início Vigência da Infração    object
#  14  Fim Vigência Infração          object
#  15  Medição Infração               float64
#  16  Medição Considerada            float64
#  17  Excesso Verificado             float64
#  18  Descrição Especie Veículo      object
#  19  Descrição Marca Veículo        object
#  20  Descrição Modelo Veiculo       object
#  21  Hora Infração                  object
# dtypes: float64(3), int64(3), object(16)
# memory usage: 1.2+ GB
# (7356159, 22)

# %% [markdown]
# **Tarefa 2: Combinação dos conjuntos de dados**

# %% [markdown]
# 1 - Gerar dois conjuntos de dados a partir da combinação dos anos: um para acidentes e um para
# multas. Nessa combinação, deve existir a identificação dos anos no próprio conjunto de dados
# utilizando multiindex.

# %%
# Com todas as colunas nomeadas da mesma forma, é possível unir tudo em um único dataframe

# INFRAÇõES 2019
infra_2019_datasets = [
    f"{infra_path}/infracoes_2019/infracoes_2019_01.csv", f"{infra_path}/infracoes_2019/infracoes_2019_02.csv",
    f"{infra_path}/infracoes_2019/infracoes_2019_03.csv", f"{infra_path}/infracoes_2019/infracoes_2019_04.csv",
    f"{infra_path}/infracoes_2019/infracoes_2019_05.csv", f"{infra_path}/infracoes_2019/infracoes_2019_06.csv",
    f"{infra_path}/infracoes_2019/infracoes_2019_07.csv", f"{infra_path}/infracoes_2019/infracoes_2019_08.csv",
    f"{infra_path}/infracoes_2019/infracoes_2019_09.csv", f"{infra_path}/infracoes_2019/infracoes_2019_10.csv",
    f"{infra_path}/infracoes_2019/infracoes_2019_11.csv", f"{infra_path}/infracoes_2019/infracoes_2019_12.csv",
]

infra_2019 = [pd.read_csv(arquivo,sep=";",encoding="utf-8", low_memory=False) for arquivo in infra_2019_datasets]
df_infra_2019 = pd.concat(infra_2019, ignore_index=True)

# INFRAÇÕES 2020
infra_2020_datasets = [
    f"{infra_path}/infracoes_2020/infracoes_2020_01.csv", f"{infra_path}/infracoes_2020/infracoes_2020_02.csv",
    f"{infra_path}/infracoes_2020/infracoes_2020_03.csv", f"{infra_path}/infracoes_2020/infracoes_2020_04.csv",
    f"{infra_path}/infracoes_2020/infracoes_2020_05.csv", f"{infra_path}/infracoes_2020/infracoes_2020_06.csv",
    f"{infra_path}/infracoes_2020/infracoes_2020_07.csv", f"{infra_path}/infracoes_2020/infracoes_2020_08.csv",
    f"{infra_path}/infracoes_2020/infracoes_2020_09.csv", f"{infra_path}/infracoes_2020/infracoes_2020_10.csv",
    f"{infra_path}/infracoes_2020/infracoes_2020_11.csv", f"{infra_path}/infracoes_2020/infracoes_2020_12.csv",
]

infra_2020 = [pd.read_csv(arquivo,sep=";",encoding="ISO-8859-1", low_memory=False) for arquivo in infra_2020_datasets]
df_infra_2020 = pd.concat(infra_2020, ignore_index=True)

# INFRAÇÕES 2021
infra_2021_datasets = [
    f"{infra_path}/infracoes_2021/infracoes_2021_01.csv", f"{infra_path}/infracoes_2021/infracoes_2021_02.csv",
    f"{infra_path}/infracoes_2021/infracoes_2021_03.csv", f"{infra_path}/infracoes_2021/infracoes_2021_04.csv",
    f"{infra_path}/infracoes_2021/infracoes_2021_05.csv", f"{infra_path}/infracoes_2021/infracoes_2021_06.csv",
    f"{infra_path}/infracoes_2021/infracoes_2021_07.csv", f"{infra_path}/infracoes_2021/infracoes_2021_08.csv",
    f"{infra_path}/infracoes_2021/infracoes_2021_09.csv", f"{infra_path}/infracoes_2021/infracoes_2021_10.csv",
    f"{infra_path}/infracoes_2021/infracoes_2021_11.csv", f"{infra_path}/infracoes_2021/infracoes_2021_12.csv",
]

infra_2021 = [pd.read_csv(arquivo,sep=";",encoding="ISO-8859-1", low_memory=False) for arquivo in infra_2021_datasets]
df_infra_2021 = pd.concat(infra_2021, ignore_index=True)

# INFRAÇÕES 2022
infra_2022_datasets = [
    f"{infra_path}/infracoes_2022/infracoes_2022_01.csv", f"{infra_path}/infracoes_2022/infracoes_2022_02.csv",
    f"{infra_path}/infracoes_2022/infracoes_2022_03.csv", f"{infra_path}/infracoes_2022/infracoes_2022_04.csv",
    f"{infra_path}/infracoes_2022/infracoes_2022_05.csv", f"{infra_path}/infracoes_2022/infracoes_2022_06.csv",
    f"{infra_path}/infracoes_2022/infracoes_2022_07.csv", f"{infra_path}/infracoes_2022/infracoes_2022_08.csv",
    f"{infra_path}/infracoes_2022/infracoes_2022_09.csv", f"{infra_path}/infracoes_2022/infracoes_2022_10.csv",
    f"{infra_path}/infracoes_2022/infracoes_2022_11.csv", f"{infra_path}/infracoes_2022/infracoes_2022_12.csv",
]

infra_2022 = [pd.read_csv(arquivo,sep=";",encoding="ISO-8859-1", low_memory=False) for arquivo in infra_2022_datasets]
df_infra_2022 = pd.concat(infra_2022, ignore_index=True)

# INFRAÇÕES 2023
infra_2023_datasets = [
    f"{infra_path}/infracoes_2023/infracoes_2023_01.csv", f"{infra_path}/infracoes_2023/infracoes_2023_02.csv",
    f"{infra_path}/infracoes_2023/infracoes_2023_03.csv", f"{infra_path}/infracoes_2023/infracoes_2023_04.csv",
    f"{infra_path}/infracoes_2023/infracoes_2023_05.csv", f"{infra_path}/infracoes_2023/infracoes_2023_06.csv",
    f"{infra_path}/infracoes_2023/infracoes_2023_07.csv", f"{infra_path}/infracoes_2023/infracoes_2023_08.csv",
    f"{infra_path}/infracoes_2023/infracoes_2023_09.csv", f"{infra_path}/infracoes_2023/infracoes_2023_10.csv",
    f"{infra_path}/infracoes_2023/infracoes_2023_11.csv", f"{infra_path}/infracoes_2023/infracoes_2023_12.csv",
]

infra_2023 = [pd.read_csv(arquivo,sep=";",encoding="ISO-8859-1", low_memory=False) for arquivo in infra_2023_datasets]
df_infra_2023 = pd.concat(infra_2023, ignore_index=True)

# INFRAÇÕES 2024
infra_2024_datasets = [
    f"{infra_path}/infracoes_2024/infracoes_2024_01.csv", f"{infra_path}/infracoes_2024/infracoes_2024_02.csv",
    f"{infra_path}/infracoes_2024/infracoes_2024_03.csv", f"{infra_path}/infracoes_2024/infracoes_2024_04.csv",
    f"{infra_path}/infracoes_2024/infracoes_2024_05.csv", f"{infra_path}/infracoes_2024/infracoes_2024_06.csv",
    f"{infra_path}/infracoes_2024/infracoes_2024_07.csv", f"{infra_path}/infracoes_2024/infracoes_2024_08.csv",
    f"{infra_path}/infracoes_2024/infracoes_2024_09.csv", f"{infra_path}/infracoes_2024/infracoes_2024_10.csv",
    f"{infra_path}/infracoes_2024/infracoes_2024_11.csv", f"{infra_path}/infracoes_2024/infracoes_2024_12.csv",
]

infra_2024 = [pd.read_csv(arquivo,sep=";",encoding="ISO-8859-1", low_memory=False) for arquivo in infra_2024_datasets]
df_infra_2024 = pd.concat(infra_2024, ignore_index=True)

# INFRAÇÕES 2025
infra_2025_datasets = [
    f"{infra_path}/infracoes_2025/infracoes_2025_01.csv", f"{infra_path}/infracoes_2025/infracoes_2025_02.csv",
    f"{infra_path}/infracoes_2025/infracoes_2025_03.csv", f"{infra_path}/infracoes_2025/infracoes_2025_04.csv",
    f"{infra_path}/infracoes_2025/infracoes_2025_05.csv", f"{infra_path}/infracoes_2025/infracoes_2025_06.csv",
    f"{infra_path}/infracoes_2025/infracoes_2025_07.csv", f"{infra_path}/infracoes_2025/infracoes_2025_08.csv",
    f"{infra_path}/infracoes_2025/infracoes_2025_09.csv", f"{infra_path}/infracoes_2025/infracoes_2025_10.csv",
    f"{infra_path}/infracoes_2025/infracoes_2025_11.csv", f"{infra_path}/infracoes_2025/infracoes_2025_12.csv",
]

infra_2025 = [pd.read_csv(arquivo,sep=";",encoding="ISO-8859-1", low_memory=False) for arquivo in infra_2025_datasets]
df_infra_2025 = pd.concat(infra_2025, ignore_index=True)

# %%
# Unindo todos os dataframes de infrações em um único dataframe
dataframes = [
    infra_2018_datasets, infra_2019_datasets, infra_2020_datasets, infra_2021_datasets,
    infra_2022_datasets, infra_2023_datasets, infra_2024_datasets, infra_2025_datasets
  ]

df_infra_final = pd.concat(dataframes, ignore_index=True)
df_infra_final.info()
df_infra_final.shape

# %%
# Todos os arquivos .csv dos acidentes seguem a mesma nomenclatura e
# quantidade de colunas, logo é possível realizar a mesclagem diretamente

# Mesclagem dos datasets de acidentes em um único dataframe
aci_datasets = [
    f"{aci_path}/acidentes_2018/datatran2018.csv", f"{aci_path}/acidentes_2019/datatran2019.csv",
    f"{aci_path}/acidentes_2020/datatran2020.csv", f"{aci_path}/acidentes_2021/datatran2021.csv",
    f"{aci_path}/acidentes_2022/datatran2022.csv", f"{aci_path}/acidentes_2023/datatran2023.csv",
    f"{aci_path}/acidentes_2024/datatran2024.csv", f"{aci_path}/acidentes_2025/datatran2025.csv"
]

dataframes = [pd.read_csv(arquivo,sep=";",encoding="ISO-8859-1") for arquivo in aci_datasets]
df_aci_final = pd.concat(dataframes, ignore_index=True)
df_aci_final.info()
df_aci_final.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543100 entries, 0 to 543099
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      543100 non-null  float64
#  1   data_inversa            543100 non-null  object
#  2   dia_semana              543100 non-null  object
#  3   horario                 543100 non-null  object
#  4   uf                      543100 non-null  object
#  5   br                      543100 non-null  int64
#  6   km                      543100 non-null  object
#  7   municipio               543100 non-null  object
#  8   causa_acidente          543100 non-null  object
#  9   tipo_acidente           543059 non-null  object
#  10  classificacao_acidente  543091 non-null  object
#  11  fase_dia                543100 non-null  object
#  12  sentido_via             543100 non-null  object
#  13  condicao_metereologica  543100 non-null  object
#  14  tipo_pista              543100 non-null  object
#  15  tracado_via             543100 non-null  object
#  16  uso_solo                543100 non-null  object
#  17  pessoas                 543100 non-null  int64
#  18  mortos                  543100 non-null  int64
#  19  feridos_leves           543100 non-null  int64
#  20  feridos_graves          543100 non-null  int64
#  21  ilesos                  543100 non-null  int64
#  22  ignorados               543100 non-null  int64
#  23  feridos                 543100 non-null  int64
#  24  veiculos                543100 non-null  int64
#  25  latitude                543100 non-null  object
#  26  longitude               543100 non-null  object
#  27  regional                543071 non-null  object
#  28  delegacia               542864 non-null  object
#  29  uop                     542670 non-null  object
# dtypes: float64(1), int64(9), object(20)
# memory usage: 124.3+ MB
# (543100, 30)
