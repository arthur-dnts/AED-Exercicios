# %% [markdown]
# ### Questão 1 — Conceitos Fundamentais
#
# Explique com suas palavras a diferença entre:
#
# a. população;
#
# b. amostra;
#
# c. parâmetro populacional;
#
# d. estatística amostral.
#
# Dê um exemplo utilizando a média de idade de estudantes de uma universidade.

# %% [markdown]
# A. A população refere-se ao conjunto total dos dados de interesse.
#
# B. A amostra refere-se a subconjuntos da população que representam o conjunto maior.
#
# C. Parâmetros populacionais são características que descrevem o conjunto da população (média, moda, mediana, etc).
#
# D. A estátistica amostral refere-se ao número calculado a partir da amostra (média amostral, variância amostral, etc).

# %% [markdown]
# ### Questão 2 — Média Amostral em Python
#
# Considere os seguintes dados:
# dados = [12, 15, 18, 20, 22, 25]
#
# a. Calcule manualmente a média amostral.
#
# b. Utilize Python e a biblioteca numpy para calcular a média.

# %% [markdown]
# A. $$ media = \frac{1}{n} \sum_{i=1}^N X_i $$
#
# - media = 112/6 ≃ 18.6
#
# B.

# %%
import pandas as pd
import numpy as np

dados = [12, 15, 18, 20, 22, 25]

media = np.mean(dados)
print(media)
# Out:
# 18.666666666666668

# %% [markdown]
# ### Questão 3 — Erro Amostral
#
# Explique por que duas amostras diferentes retiradas da mesma população podem produzir médias
# diferentes.
#
# Defina o conceito de erro amostral.

# %% [markdown]
# - As duas amostras podem apresentar médias distintas por se tratarem de subconjuntos distintos de um conjunto maior, cada amostra possui seus próprios elementos, podendo ser uma amostra mais homogênea, enquanto a outra mais variável, a presença de outliers também podem influenciar no resultado final da média.
#
# - Erro amostral é a diferença entre a estatística amostral e o parâmetro populacional, é um desvio natural que surge após a estimativa em parte dos dados e não no conjunto completo.

# %% [markdown]
# ### Questão 4 — Simulação de Médias Amostrais
#
# Utilize Python para:
# - gerar uma população com distribuição normal;
# - extrair 100 amostras aleatórias de tamanho 30;
# - calcular a média de cada amostra.
# Depois:
#
# a. armazene as médias em uma lista;
#
# b. calcule a média das médias amostrais.

# %%
import numpy as np

populacao = np.random.normal(loc=50, scale=10, size=100000)

n_amostras = 100
tamanho_amostra = 30

medias_amostrais = []

for _ in range(n_amostras):
    amostra = np.random.choice(populacao, size=tamanho_amostra, replace=False)
    medias_amostrais.append(np.mean(amostra))

print("Média das médias:", np.mean(medias_amostrais))
print("Desvio padrão das médias:", np.std(medias_amostrais))
# Out:
# Média das médias: 49.74511757630366
# Desvio padrão das médias: 1.8475788480972053

# %% [markdown]
# ### Questão 5 — Distribuição Amostral
#
# Explique o que é uma distribuição amostral da média.
#
# Por que ela é importante para a inferência estatística?

# %% [markdown]
# - A distribuição amostral da média é a distribuição de todas as médias extraídas de todas as amostras do mesmo tamanho da população.
#
# - Ela é importante porque descreve como a média amostral varia entre diferentes amostrar. A partir dela é possível calcular o erro padrão, intervalos de confiança e testes hipotéticos.

# %% [markdown]
# ### Questão 6 — Intervalo de Confiança
# Explique o significado de um intervalo de confiança de 95%.
#
# Interprete o seguinte resultado:
#
# $ IC_{(95\%)} = [12.4, 18.7] $

# %% [markdown]
# - Um intervalo de confiança de 95% é um intervalo construído a partir de uma amostra, de forma que, se o processo for repetido infinitas vezes, produzirá intervalos que contêm o verdadeiro parâmetro em 95% das repetições.
#
# - O intervalo de confiança apresentado vai de 12.4 a 18.7, se o processo de amostragem fosse repetido múltiplas vezes, 95% dos intervalos produzidos conteriam o verdadeiro valor do parâmetro populacional.

# %% [markdown]
# ### Questão 7 — Erro Padrão
# Considere o conjunto de dados:
#
# ```python
# import numpy as np
# dados = [5, 8, 9, 10, 12, 15, 18]
# ```
#
# a. Calcule o desvio padrão amostral.
#
# b. Calcule o erro padrão da média.
#
# Utilize Python em sua resposta.

# %%
dados = [5, 8, 9, 10, 12, 15, 18]

desvio = np.std(dados)
print(f"Desvio-Padrão: {desvio}")

erro_padrao = desvio/np.sqrt(len(dados))
print(f"Erro Padrão: {erro_padrao}")
# Out:
# Desvio-Padrão: 4.0708019567928595
# Erro Padrão: 1.5386185163241441

# %% [markdown]
# ### Questão 8 — Interpretação do Erro Padrão
#
# Explique com suas palavras a relação entre tamanho da amostra e erro padrão.

# %% [markdown]
# - A relação entre o tamanho e o erro padrão é que o erro padrão é calculado a partir da razão entre o desvio-padrão e a raiz quadrada do tamanho da amostra, ou seja, o erro é relativo à quantidade de elementos da amostra, ou seja, quanto maior o tamanho da amostra, menor o erro.

# %% [markdown]
# ### Questão 9 — Teorema Central do Limite
#
# Escreva um código em Python que:
# - gere valores aleatórios de uma distribuição exponencial;
# - extraia várias amostras;
# - calcule as médias das amostras;
# - construa um histograma das médias.
#
# O que você observa no formato do histograma?

# %%
import matplotlib.pyplot as plt
import numpy as np

dados = np.random.exponential(scale=1/0.5, size=1000)
n_amostras = 100
tamanho = 30

medias_amostrais = []

for _ in range(n_amostras):
    amostra = np.random.choice(dados, tamanho, replace=True)
    medias_amostrais.append(np.mean(amostra))

plt.hist(medias_amostrais, bins=20)
plt.title("Distribuição das Médias Amostrais")
plt.xlabel("Média")
plt.ylabel("Frequência")
plt.show()

# %% [markdown]
# - É possível inferir que a distribuição amostral das médias é normal, os valores tendem a se concentrar em torno da verdadeira média populacional e há poucos valores extremos (outliers).

# %% [markdown]
# ### Questão 10 — Comparação entre Amostras
#
# Considere dois estudos:
# - Estudo A: n = 10
# - Estudo B: n = 200
#
# Qual estudo tende a produzir
# estimativas mais estáveis da média populacional?
#
# Justifique sua resposta.

# %% [markdown]
# - O estudo B, visto que quanto maior a quantidade o tamanho da amostra, menor o erro, ou seja, mais estáveis serão os valores da média populacional.

# %% [markdown]
# ### Questão 11 — Intervalo de Confiança com SciPy
#
# Utilize as bibliotecas numpy e scipy.stats para calcular um intervalo de confiança para a média dos
# dados:
#
# dados = [22, 25, 21, 20, 26, 24, 23, 27]

# %%
import numpy as np
import scipy.stats

dados = [22, 25, 21, 20, 26, 24, 23, 27]

media = np.mean(dados)
desvio = np.std(dados)
erro_padrao = desvio/np.sqrt(len(dados))
sem = scipy.stats.sem(dados)

ic = scipy.stats.t.interval(confidence=0.95, df=len(dados)-1, loc=media, scale=sem)

print("Média:", media)
print("Intervalo de confiança 95%:", (f"{float(ic[0]):.2f}", f"{float(ic[1]):.2f}"))
# Out:
# Média: 23.5
# Intervalo de confiança 95%: ('21.45', '25.55')

# %% [markdown]
# ### Questão 12 — Precisão da Estimativa
#
# Dois pesquisadores obtiveram os seguintes intervalos de confiança:
# - Pesquisa A: [15, 16]
# - Pesquisa B: [10, 22]
#
# Qual pesquisa apresenta maior precisão na estimativa? Explique.

# %% [markdown]
# - A pesquisa A apresenta uma maior precisão, visto que os valores são muito próximos entre si, pois, quanto menor a largura do intervalo, mais precisa é a estimativa da média populacional.

# %% [markdown]
# ### Questão 13 — Variabilidade das Médias
# Escreva um programa em Python que:
# - gere 50 amostras aleatórias de tamanho 5;
# - gere 50 amostras aleatórias de tamanho 100;
# - compare a variabilidade das médias obtidas.
#
# O que acontece quando o tamanho da amostra aumenta?

# %%
import matplotlib.pyplot as plt
import numpy as np

dados = np.random.exponential(scale=1/0.5, size=1000)
n_amostras = 50
tamanho_a = 5
tamanho_b = 100

medias_a = []
medias_b = []

for _ in range(n_amostras):
    amostra = np.random.choice(dados, tamanho_a, replace=True)
    medias_a.append(np.mean(amostra))

for _ in range(n_amostras):
    amostra = np.random.choice(dados, tamanho_b, replace=True)
    medias_b.append(np.mean(amostra))

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.hist(medias_a, bins=20)
plt.title("Médias Amostrais - A = 5")
plt.xlabel("Média")
plt.ylabel("Frequência")

plt.subplot(1, 2, 2)
plt.hist(medias_b, bins=20)
plt.title("Médias Amostrais - B = 100")
plt.xlabel("Média")
plt.show()

# %% [markdown]
# - Ao aumentar o tamanho da amostra, a média tende a se concentrar mais próxima do valor real da média populacional

# %% [markdown]
# ### Questão 14 — Estimativa Pontual e Intervalar
#
# Explique a diferença entre:
# - estimativa pontual;
# - estimativa intervalar.
#
# Dê exemplos utilizando a média salarial de trabalhadores.

# %% [markdown]
# - A estimativa pontual é a utilização de um único ponto ou valor para estimar um parâmetro desconhecido da população.
#
# - A estimativa intervalar é um intervalo de valores dentro do qual o parâmetro populacional deve estar, com um certo nível de confiança.
